# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalChaudhari8/BRAIN_TUMOR_APP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mmh3
# !pip install bitarray

# %%
# Loading Library
from nltk.corpus import stopwords

# Using stopwords from English Languages
english_stops = set(stopwords.words('english'))

# Printing stopword list present in English
words = ["Let's", 'see', 'how', "it's", 'working']

print ("Before stopwords removal: ", words)
print ("\nAfter stopwords removal : ",
       [word for word in words if word not in english_stops])
# Out:
# Before stopwords removal:  ["Let's", 'see', 'how', "it's", 'working']
#
# After stopwords removal :  ["Let's", 'see', 'working']

# %% [markdown]
# # New Section

# %%
pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download required resource (only needed once)
nltk.download('punkt_tab')

# Input text
text = "Tokenization is crucial for NLP."

# Tokenization
word_tokens = word_tokenize(text)

# Output
print("Word Tokens:", word_tokens)
# Out:
# Word Tokens: ['Tokenization', 'is', 'crucial', 'for', 'NLP', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import nltk

# Remove the punkt folder first (optional but recommended for corrupted downloads)
import shutil
shutil.rmtree('/root/nltk_data/tokenizers/punkt', ignore_errors=True)

# Re-download punkt
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
